# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
AOI = np.array([0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75])

T_405 = np.array([95.4177, 95.1773, 95.3925, 95.6155, 96.2245, 96.0769, 97.0515, 
                  97.2016, 97.0179, 96.9913, 95.8855, 93.8862, 89.2597, 83.5251, 75.0928, 58.6013])
R_405 = np.array([0, 0, 2.25004, 2.30872, 2.07467, 1.75352, 1.84089, 
                  1.7643, 2.02767, 2.6512, 3.79725, 5.93216, 9.36772, 16.1359, 25.809, 39.4618])

T_450 = np.array([97.0024, 96.6845, 96.3104, 97.3059, 96.9245, 96.8754, 97.0391, 
                  96.895, 96.8631, 94.8637, 88.1433, 71.0125, 51.5083, 39.133, 30.6678, 23.2737])
R_450 = np.array([0, 0, 1.79786, 1.72688, 1.67175, 1.75181, 1.40398, 
                  2.00416, 2.67594, 4.78171, 12.0145, 27.2272, 47.5384, 61.1899, 69.4671, 74.8301])

T_505 = np.array([93.7187, 92.6823, 90.9232, 87.8986, 82.1152, 73.3838, 54.4588, 
                  29.0425, 12.3399, 3.96907, 1.23147, 0.541923, 0.173513, 0.179266, 0.332252, 0.39132])
R_505 = np.array([0, 0, 9.433, 13.1957, 18.4381, 25.6663, 45.3148, 
                  71.2668, 88.6574, 95.9359, 99.649, 99.6258, 101.344, 101.046, 99.3979, 97.6089])

# Plot with style similar to second image
plt.figure(figsize=(12,8))

plt.plot(AOI, T_405/100, 'bo:', label='%T (405 nm LED)')
plt.plot(AOI, R_405/100, 'ro:', label='%R (405 nm LED)')
plt.plot(AOI, T_450/100, 'bo--', label='%T (450 nm LED)')
plt.plot(AOI, R_450/100, 'ro--', label='%R (450 nm LED)')
plt.plot(AOI, T_505/100, 'bo-', label='%T (505 nm LED)')
plt.plot(AOI, R_505/100, 'ro-', label='%R (505 nm LED)')

plt.xlim(0,75)
plt.xlabel('AOI (degrees)')
plt.ylabel('%T and %R')
plt.title('Edmund 510 nm Short Pass Diechrioc Filter - Transmission & Reflection vs. AOI')
plt.legend()
plt.grid(True, linestyle='--', linewidth=0.5)

plt.show()
